# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pymc3 as pm
import arviz as az
import corner

from glob import glob
from scipy.optimize import curve_fit
from astropy.cosmology import Planck18 as cosmo

# %%
pwd
# Out:
# '/home/jjahns/Visibilities'

# %%
textwidth = 7.0282  # might also be from latex textwidth=17.85162cm columnwidth=8.5744cm
columnwidth = 3.37574803  #3.3

small_size = 8
medium_size = 10
bigger_size = 12

sns.set_theme(style="ticks", context="paper")

# plt.rc('font', size=small_size)          # controls default text sizes
# plt.rc('axes', titlesize=small_size)     # fontsize of the axes title
# plt.rc('axes', labelsize=medium_size)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=small_size)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=small_size)    # fontsize of the tick labels
# plt.rc('legend', fontsize=small_size)    # legend fontsize
# plt.rc('figure', titlesize=bigger_size)  # fontsize of the figure title

# %%
# Files to do corner plots for.
files = sorted(glob("Posteriors/chime-frb_SDSS*.nc"))
files
# Out:
# ['Posteriors/chime-frb_SDSS_124_zs_20x1500_draws.nc',
#  'Posteriors/chime-frb_SDSS_random_sample_of_124_zs_run_0_20x1500_draws.nc',
#  'Posteriors/chime-frb_SDSS_random_sample_of_124_zs_run_1_20x1500_draws.nc',
#  'Posteriors/chime-frb_SDSS_random_sample_of_124_zs_run_2_20x1500_draws.nc']

# %%
Obh70, F, mu, lognorm_s = cosmo.Ob0*cosmo.H0.value/70, .2, 100, 1

for file in files[:]:
    idata = az.from_netcdf(file)
    
    # fig = plt.figure(figsize=(columnwidth, columnwidth))
    fig = corner.corner(idata, color='k', 
                        var_names=['Obh70', 'F', 'mu', 'lognorm_s'], 
                        labels=['$\Omega_\mathrm{b} h_{70}$', '$F$', r'$\mathrm{DM}_\mathrm{host}/\mathrm{pc}\,\mathrm{cm}^{-3}$', '$\sigma_\mathrm{host}$'],
                        range=[(0.025, 0.065), (0.011, .5), (20, 200), (0.5, 1.8)],  # CHIME + SDSS
                        # range=[(0.038, 0.055), (0.1, .5), (60, 160), (0.6, 1.2)],  # ASKAP + DELVE
                        truths=[Obh70, F, mu, lognorm_s])
    
    # Set some ticks manually (to prevent them from getting too long).
    # fig.get_axes()[4].set_yticks(np.arange(3, 7)*0.01)
    # fig.get_axes()[-3].set_xticks(np.arange(3, 7)*0.01)
    
    fig.savefig(f"figures/{os.path.splitext(os.path.basename(file))[0]}.png", dpi=300, bbox_inches='tight')

# %%
# Calculate the ratio of the observed FRB constrains with the randomly drawn FRBs.
idata = az.from_netcdf('Posteriors/chime-frb_SDSS_124_zs_20x1500_draws.nc')
hdi95 = az.hdi(idata.posterior, hdi_prob=0.95).to_array().to_pandas()
hdi95_diff = hdi95.loc[:, 'higher']-hdi95.loc[:, 'lower']
idata = az.from_netcdf('Posteriors/chime-frb_SDSS_random_sample_of_124_zs_run_1_20x1500_draws.nc')
hdi95 = az.hdi(idata.posterior, hdi_prob=0.95).to_array().to_pandas()
hdi95_diff_rnd = hdi95.loc[:, 'higher']-hdi95.loc[:, 'lower']
hdi95_diff/hdi95_diff_rnd
# Out:
# variable
# Obh70        2.564859
# F            2.180576
# mu           0.681348
# lognorm_s    0.543266
# dtype: float64

# %%
# Files for which to plot the credible interval.
files = sorted(glob("Posteriors/askap-craco_DES_[0-9]*.nc"))
files
# Out:
# ['Posteriors/askap-craco_DES_101_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_10_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_116_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_11_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_133_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_13_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_153_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_15_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_175_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_17_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_19_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_201_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_22_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_230_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_264_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_26_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_29_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_303_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_347_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_34_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_398_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_39_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_44_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_457_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_51_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_523_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_524_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_58_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_5_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_67_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_77_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_7_zs_20x1500_draws.nc',
#  'Posteriors/askap-craco_DES_88_zs_20x1500_draws.nc']

# %%
quantiles = []
hdi95 = []
n_frbs = np.zeros(len(files), dtype=int)
for i, post_path in enumerate(files):
    n_frbs[i] = os.path.split(post_path)[-1].split('_')[2]
    idata = az.from_netcdf(post_path)
    quantiles.append(idata.posterior.quantile([.05, .5, .95]).to_array().to_pandas())
    hdi95.append(az.hdi(idata.posterior, hdi_prob=0.95).to_array().to_pandas())

quantiles = pd.concat(quantiles, axis=0)
hdi95 = pd.concat(hdi95, axis=0)

# %%
hdi95
# Out:
# hdi            lower      higher
# variable
# Obh70       0.038080    0.055747
# F           0.084177    0.471703
# mu         90.469719  180.770732
# lognorm_s   0.742321    1.211266
# Obh70       0.033266    0.067222
# ...              ...         ...
# lognorm_s   0.266678    1.827437
# Obh70       0.036754    0.054538
# F           0.067314    0.452449
# mu         92.749018  190.881354
# lognorm_s   0.770780    1.259841
#
# [132 rows x 2 columns]

# %%
var, true_val = 'Obh70', Obh70
median = quantiles.loc[var, 0.5]
plt.errorbar(n_frbs, median, 
             yerr=pd.concat([median-hdi95.loc[var, 'lower'], hdi95.loc[var, 'higher']-median], axis=1).to_numpy().T, 
             fmt='.')

plt.axhline(true_val, label="True value")

plt.xlabel("$n_\mathrm{FRBs}$")
plt.ylabel('$\Omega_b h_{70}$')
#plt.xscale('log')
plt.legend()
plt.savefig("Obh_vs_nFRBs.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
var='Obh70'
hdi95_diff = hdi95.loc[var, 'higher']-hdi95.loc[var, 'lower']
hdi95_diff
# Out:
# variable
# Obh70    0.017667
# Obh70    0.033957
# Obh70    0.016726
# Obh70    0.033847
# Obh70    0.016467
# Obh70    0.032427
# Obh70    0.015195
# Obh70    0.029134
# Obh70    0.014678
# Obh70    0.027985
# Obh70    0.025795
# Obh70    0.013983
# Obh70    0.024119
# Obh70    0.013121
# Obh70    0.011654
# Obh70    0.021460
# Obh70    0.020714
# Obh70    0.012045
# Obh70    0.011034
# Obh70    0.020676
# Obh70    0.010803
# Obh70    0.020755
# Obh70    0.020519
# Obh70    0.009752
# Obh70    0.020116
# Obh70    0.009889
# Obh70    0.009797
# Obh70    0.020247
# Obh70    0.047480
# Obh70    0.019597
# Obh70    0.018912
# Obh70    0.035254
# Obh70    0.017784
# dtype: float64

# %%
fig, axs = plt.subplots(4, 1, sharex=True, gridspec_kw={'hspace':0.04}, figsize=(columnwidth, 4*columnwidth/6.4*4.8))
for ax, var, true_val, plot_name in zip(axs, ['Obh70', 'F', 'mu', 'lognorm_s'], [Obh70, F, mu, lognorm_s],
        ['$\Omega_\mathrm{b} h_{70}$', '$F$', r'$\mathrm{DM}_\mathrm{host}/\mathrm{pc}\,\mathrm{cm}^{-3}$', 
         '$\sigma_\mathrm{host}$']):
    # fig, ax = plt.subplots()
    # Plot credible intervals against FRB numbers.
    hdi95_diff = hdi95.loc[var, 'higher']-hdi95.loc[var, 'lower']
    #mean_hdi = hdi95_diff / 2
    sns.scatterplot(x=n_frbs, y=hdi95_diff, label="Simulated", ax=ax, legend=False)
    #plt.plot(n_frbs, median-hdi95.loc[var, 'lower'], '.', label="Simulated")

    if var == 'Obh70':
        # Macquarts results
        rel_uncert = np.array([.31, .28])
        abs_uncert = np.array([.014+.015, .011+.012])
        sns.scatterplot(x=[5, 7], y=rel_uncert*Obh70*2*2, ax=ax, label="Macquart et al. (2020)\n4x 68% confidence", marker='*', s=100) #abs_uncert
        ax.legend()

    # Fit 1/sqrt function.
    # popt, pcov = curve_fit(lambda x, a: a/np.sqrt(x), n_frbs, hdi95_diff)
    # x = np.logspace(np.log10(4), np.log10(700), 30)
    # plt.plot(x, popt[0]/np.sqrt(x), zorder=.1, label=f"{popt[0]:2.2}"+"$/\sqrt{n_\mathrm{FRBs}}$")

    ax.set_ylabel(f"{plot_name}\n 95% credible interval")
    ax.set_ylim(0, None)
    ax.xaxis.set_tick_params(length=3)

    # Put a percent axis on the right
    # ax = plt.gca()
    ax2 = ax.twinx()
    y2_minmax = np.array(ax.get_ylim())/true_val*100
    ax2.set_ylim(y2_minmax)
    y2ticks = np.arange(*y2_minmax, 20, dtype=int)
    ax2.set_yticks(y2ticks, labels=[str(tick)+"%" for tick in y2ticks])
    ax2.set_ylabel("relative to input value")

ax.set_xlabel("$n_\mathrm{FRBs}$")
plt.savefig(f"figures/ASKAP-DES_95ci_vs_nFRBs.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Maximum CI relative to input value
var = 'Obh70'
(hdi95.loc[var, 'higher']-hdi95.loc[var, 'lower'])[n_frbs==n_frbs.max()]/Obh70
# Out:
# variable
# Obh70    0.206973
# dtype: float64

# %%
isort = n_frbs.argsort()

# %%
np.sort(n_frbs), hdi95_diff[isort]
# Out:
# (array([  5,   7,  10,  11,  13,  15,  17,  19,  22,  26,  29,  34,  39,
#          44,  51,  58,  67,  77,  88, 101, 116, 133, 153, 175, 201, 230,
#         264, 303, 347, 398, 457, 523, 524]),
#  variable
#  Obh70    0.047480
#  Obh70    0.035254
#  Obh70    0.033957
#  Obh70    0.033847
#  Obh70    0.032427
#  Obh70    0.029134
#  Obh70    0.027985
#  Obh70    0.025795
#  Obh70    0.024119
#  Obh70    0.021460
#  Obh70    0.020714
#  Obh70    0.020676
#  Obh70    0.020755
#  Obh70    0.020519
#  Obh70    0.020116
#  Obh70    0.020247
#  Obh70    0.019597
#  Obh70    0.018912
#  Obh70    0.017784
#  Obh70    0.017667
#  Obh70    0.016726
#  Obh70    0.016467
#  Obh70    0.015195
#  Obh70    0.014678
#  Obh70    0.013983
#  Obh70    0.013121
#  Obh70    0.011654
#  Obh70    0.012045
#  Obh70    0.011034
#  Obh70    0.010803
#  Obh70    0.009752
#  Obh70    0.009889
#  Obh70    0.009797
#  dtype: float64)

# %%
n_frbs, quantiles.loc[var, 0.5]
# Out:
# (array([101,  10, 116,  11, 133,  13, 153,  15, 175,  17,  19, 201,  22,
#         230, 264,  26,  29, 303, 347,  34, 398,  39,  44, 457,  51, 523,
#         524,  58,  67,  77,  88]),
#  variable
#  Obh70    0.046899
#  Obh70    0.049292
#  Obh70    0.046284
#  Obh70    0.050105
#  Obh70    0.048787
#  Obh70    0.052573
#  Obh70    0.049751
#  Obh70    0.051882
#  Obh70    0.047788
#  Obh70    0.050646
#  Obh70    0.047611
#  Obh70    0.046677
#  Obh70    0.049894
#  Obh70    0.046129
#  Obh70    0.043649
#  Obh70    0.048450
#  Obh70    0.048300
#  Obh70    0.046131
#  Obh70    0.045703
#  Obh70    0.048486
#  Obh70    0.045815
#  Obh70    0.047924
#  Obh70    0.048474
#  Obh70    0.046579
#  Obh70    0.047994
#  Obh70    0.046351
#  Obh70    0.046606
#  Obh70    0.048460
#  Obh70    0.047212
#  Obh70    0.045963
#  Obh70    0.044792
#  Name: 0.5, dtype: float64)

# %%
for var, true_val in zip(['Obh70', 'F', 'mu', 'lognorm_s'], [Obh70, F, mu, lognorm_s]):
    plt.plot(n_frbs, quantiles.loc[var, 0.5], '.', label="median")
    plt.plot(n_frbs, quantiles.loc[var, 0.95], '.', label="90% confidence interval", color="orange")
    plt.plot(n_frbs, quantiles.loc[var, 0.05], '.', color="orange")

    plt.axhline(true_val, label="True value")

    plt.xlabel("$n_\mathrm{FRBs}$")
    plt.ylabel(var)
    plt.legend()

    plt.show()

# %%
Obh70
# Out:
# 0.04733300285714285

# %%
#fig, ax = plt.subplots(4)
for var in ['Obh70', 'F', 'mu', 'lognorm_s']:
    plt.plot(n_frbs, interval_95[var], '.', label=var)

    plt.xlabel("$n_\mathrm{FRBs}$")
    plt.ylabel("90% confidence interval")
    plt.ylim(0, None)
    plt.legend()

    plt.show()

# %%
interval_95['Obh70'].min()
# Out:
# 0.009657388631829918
